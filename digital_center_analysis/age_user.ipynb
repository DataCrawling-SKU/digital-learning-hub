# %%
import pandas as pd

# %%
age_df = pd.read_csv('C:/Users/wjdah/vscode-workspace/digital-learning-hub/digital_center_analysis/dataFile/age_learning.csv', sep=',', header=0, engine='python')

# %%
age_df
# Out:
#       연도     연령  디지털 배움터 교육인원(명)
# 0   2020  10대이하            90759
# 1   2020    20대            38977
# 2   2020    30대            37178
# 3   2020    40대            78600
# 4   2020    50대            59640
# 5   2020    60대            59127
# 6   2020  70대이상            46870
# 7   2020   연령미상            16952
# 8   2021  10대이하           137500
# 9   2021    20대            26816
# 10  2021    30대            30395
# 11  2021    40대            80762
# 12  2021    50대            89088
# 13  2021    60대           128349
# 14  2021  70대이상           162844
# 15  2021   연령미상              526
# 16  2022  10대이하           128003
# 17  2022    20대            27068
# 18  2022    30대            27045
# 19  2022    40대            68701
# 20  2022    50대            91465
# 21  2022    60대           167212
# 22  2022  70대이상           270796
# 23  2022   연령미상            12358
# 24  2023  10대이하           160888
# 25  2023    20대            29540
# 26  2023    30대            29396
# ...

# %%
age_df.describe()
# Out:
#                연도  디지털 배움터 교육인원(명)
# count    40.00000        40.000000
# mean   2022.00000     85478.250000
# std       1.43223     80062.856681
# min    2020.00000       526.000000
# 25%    2021.00000     28814.000000
# 50%    2022.00000     62902.500000
# 75%    2023.00000    123219.500000
# max    2024.00000    372478.000000

# %%
age_df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
age_df = age_df.drop([age_df.index[32], age_df.index[33], age_df.index[34], age_df.index[35], age_df.index[36], age_df.index[37], age_df.index[38], age_df.index[39]])
age_df
# Out:
#       연도     연령  디지털 배움터 교육인원(명)
# 0   2020  10대이하            90759
# 1   2020    20대            38977
# 2   2020    30대            37178
# 3   2020    40대            78600
# 4   2020    50대            59640
# 5   2020    60대            59127
# 6   2020  70대이상            46870
# 7   2020   연령미상            16952
# 8   2021  10대이하           137500
# 9   2021    20대            26816
# 10  2021    30대            30395
# 11  2021    40대            80762
# 12  2021    50대            89088
# 13  2021    60대           128349
# 14  2021  70대이상           162844
# 15  2021   연령미상              526
# 16  2022  10대이하           128003
# 17  2022    20대            27068
# 18  2022    30대            27045
# 19  2022    40대            68701
# 20  2022    50대            91465
# 21  2022    60대           167212
# 22  2022  70대이상           270796
# 23  2022   연령미상            12358
# 24  2023  10대이하           160888
# 25  2023    20대            29540
# 26  2023    30대            29396
# ...

# %%
# 연도별 배움터 교육인원 합계 구하기
year_df_sum = age_df.groupby('연도')['디지털 배움터 교육인원(명)'].sum().reset_index() # reset_index를 써서 데이터프레임으로 만듦
year_df_sum
# Out:
#      연도  디지털 배움터 교육인원(명)
# 0  2020           428103
# 1  2021           656280
# 2  2022           792648
# 3  2023           996439

# %%
# 연령별 배움터 교육인원 합계 구하기
age_df_sum = age_df.groupby('연령')['디지털 배움터 교육인원(명)'].sum().reset_index() # reset_index를 써서 데이터프레임으로 만듦
age_df_sum
# Out:
#       연령  디지털 배움터 교육인원(명)
# 0  10대이하           517150
# 1    20대           122401
# 2    30대           124014
# 3    40대           300705
# 4    50대           337683
# 5    60대           563078
# 6  70대이상           852988
# 7   연령미상            55451

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tk

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(12, 5))

plt.bar(year_df_sum['연도'], year_df_sum['디지털 배움터 교육인원(명)'], color='skyblue')

plt.title('연도별 배움터 교육인원')
plt.xlabel('연도')
plt.ylabel('교육인원')

plt.gca().ticklabel_format(style='plain', axis='y')
plt.gca().yaxis.set_major_formatter(tk.StrMethodFormatter('{x:,.0f}'))

plt.xticks([2020, 2021, 2022, 2023])

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tk

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(17, 5))

age_df_sum.index = ['10대이하', '20대', '30대', '40대', '50대', '60대', '70대이상', '연령미상']
colors = ['skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue', 'red', 'red', 'skyblue',]

plt.bar(age_df_sum.index, age_df_sum['디지털 배움터 교육인원(명)'], color=colors)

plt.title('연령별 배움터 교육인원')
plt.xlabel('연령')
plt.ylabel('교육인원')

plt.gca().ticklabel_format(style='plain', axis='y') # 과학적 표기 제거
plt.gca().yaxis.set_major_formatter(tk.StrMethodFormatter('{x:,.0f}')) # 천단위로 , 표시

plt.show()
