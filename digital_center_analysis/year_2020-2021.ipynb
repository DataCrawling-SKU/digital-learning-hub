# %%
import pandas as pd

# %%
age_df = pd.read_csv('C:/Users/wjdah/vscode-workspace/digital-learning-hub/digital_center_analysis/dataFile/age_learning.csv', sep=',', header=0, engine='python')

# %%
age_df = age_df[age_df['연도'].isin([2020, 2021])]

# %%
age_year_sum = age_df.groupby('연도')['디지털 배움터 교육인원(명)'].sum()

# %%
age_year_sum.to_csv('2022-2021_age_sum.csv', encoding='utf-8-sig')
print(age_year_sum)
# Out:
# 연도
# 2020    428103
# 2021    656280
# Name: 디지털 배움터 교육인원(명), dtype: int64
